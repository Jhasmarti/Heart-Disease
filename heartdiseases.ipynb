# %% [markdown]
# # Heart Disesases

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\91991\Downloads\archive (1)\heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
print("*******************************Data shape******************************************\n")
print(df.shape)
print("************************************Data Info************************************\n")
print(df.info)
print("*************************************Check data null value**********************************\n")
print(df.isnull().sum())
print("***************************************Statistical Represent***********************************\n")
print(df.describe())
print("****************************Count the value of patient have heart diseases(1)****************************\n")
print(df['target'].value_counts())
# Out:
# *******************************Data shape******************************************
#
# (1025, 14)
# ************************************Data Info************************************
#
# <bound method DataFrame.info of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# ...

# %% [markdown]
# # Machine Learning Classification

# %%
import numpy as np
import pandas as pd
#data
df=pd.read_csv(r"C:\Users\91991\Downloads\archive (1)\heart.csv")
#independent and dependent variable
x=df.drop('target',axis=1)
y=df['target']
def LogisticRegression():
    print("*****************************LogisticRegression********************************************")
    ##Training testing data
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
     ##MAchine learnig alogrithm
    from sklearn.linear_model import LogisticRegression
    model=LogisticRegression()
    model.fit(x_train,y_train)
    accuracy=model.score(x_test,y_test)
    print(accuracy)
    print("*****************************Predication on new data********************************************")
    input_data=(59,1,1,140,221,0,1,164,1,0.0,2,0,2)
    pred=np.array(input_data)
    print("New patient data:",pred)
    predict=pred.reshape(1,-1)
    print("After Reshape data ",predict)
    prediction=model.predict(predict)
    if (prediction[0]==0):
        print("Patient has no heart diseases")
    else:
        print("Heart patient")

# %%
import numpy as np
import pandas as pd
#data
df=pd.read_csv(r"C:\Users\91991\Downloads\archive (1)\heart.csv")
#independent and dependent variable
x=df.drop('target',axis=1)
y=df['target']
def KNearestNeighbors():
    print("*****************************KNearestNeighbors********************************************")
    ##Training testing data
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
    from sklearn.neighbors import KNeighborsClassifier
    model=KNeighborsClassifier()
    model.fit(x_train,y_train)
    accuracy=model.score(x_test,y_test)
    print(accuracy)
    print("*****************************Predication on new data********************************************")
    input_data=(59,1,1,140,221,0,1,164,1,0.0,2,0,2)
    pred=np.array(input_data)
    print("New patient data:",pred)
    predict=pred.reshape(1,-1)
    print("After Reshape data ",predict)
    prediction=model.predict(predict)
    if (prediction[0]==0):
        print("Patient has no heart diseases")
    else:
        print("Heart patient")

# %%
import numpy as np
import pandas as pd
#data
df=pd.read_csv(r"C:\Users\91991\Downloads\archive (1)\heart.csv")
#independent and dependent variable
x=df.drop('target',axis=1)
y=df['target']
def NaiveBayes():
    print("*****************************NaiveBayes********************************************")
    ##Training testing data
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
    ##MAchine learnig alogrithm
    from sklearn.naive_bayes import GaussianNB
    model=GaussianNB()
    model.fit(x_train,y_train)
    accuracy=model.score(x_test,y_test)
    print(accuracy)
    print("*****************************Predication on new data********************************************")
    input_data=(59,1,1,140,221,0,1,164,1,0.0,2,0,2)
    pred=np.array(input_data)
    print("New patient data:",pred)
    predict=pred.reshape(1,-1)
    print("After Reshape data ",predict)
    prediction=model.predict(predict)
    if (prediction[0]==0):
        print("Patient has no heart diseases")
    else:
        print("Heart patient")

# %%
import numpy as np
import pandas as pd
#data
df=pd.read_csv(r"C:\Users\91991\Downloads\archive (1)\heart.csv")
#independent and dependent variable
x=df.drop('target',axis=1)
y=df['target']
def SVC():
    print("*****************************Support Vector Machine********************************************")
    ##Training testing data
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
     ##MAchine learnig alogrithm
    from sklearn.svm import SVC
    model=SVC(kernel='rbf')
    model.fit(x_train,y_train)
    accuracy=model.score(x_test,y_test)
    print(accuracy)
    print("*****************************Predication on new data********************************************")
    input_data=(59,1,1,140,221,0,1,164,1,0.0,2,0,2)
    pred=np.array(input_data)
    print("New patient data:",pred)
    predict=pred.reshape(1,-1)
    print("After Reshape data ",predict)
    prediction=model.predict(predict)
    if (prediction[0]==0):
        print("Patient has no heart diseases")
    else:
        print("Heart patient")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#data
df=pd.read_csv(r"C:\Users\91991\Downloads\archive (1)\heart.csv")
#independent and dependent variable
x=df.drop('target',axis=1)
y=df['target']
def DecisionTree():
    print("*****************************DecisionTree********************************************")
    ##Training testing data
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
     ##MAchine learnig alogrithm
    from sklearn.tree import DecisionTreeClassifier
    model=DecisionTreeClassifier()
    model.fit(x_train,y_train)
    accuracy=model.score(x_test,y_test)
    print(accuracy)
    print("*****************************Predication on new data********************************************")
    input_data=(59,1,1,140,221,0,1,164,1,0.0,2,0,2)
    pred=np.array(input_data)
    print("New patient data:",pred)
    predict=pred.reshape(1,-1)
    print("After Reshape data ",predict)
    prediction=model.predict(predict)
    if (prediction[0]==0):
        print("Patient has no heart diseases")
    else:
        print("Heart patient")

# %%
print("1. For Logistic Regression ")
print("2. For K-Nearest Neighbors ")
print("3. For Decision Tree ")
print("4. For Support Vector Machines")
print("5. For Naive Bayes")

n=int(input("Enter your choose:"))
if(n==1):
    LogisticRegression()
elif(n==2):
    KNearestNeighbors()
elif(n==3):
    DecisionTree()
elif(n==4):
    SVC()
elif(n==5):
    NaiveBayes()
else:
    print("Invaild")
# Out:
# 1. For Logistic Regression
# 2. For K-Nearest Neighbors
# 3. For Decision Tree
# 4. For Support Vector Machines
# 5. For Naive Bayes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x=df['trestbps'],y=df['age'],data=df)
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='age'>

# %%
sns.distplot(x=df['trestbps'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import matplotlib.pyplot as plt
plt.plot(df['chol'])

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...
